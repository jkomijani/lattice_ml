# %% [markdown]
# # Diffusion Model: SU3 gauge theory on $16^2$ lattice
#
# *Sep 24, 2025*
#
# **[Javad Komijani (ETH Zurich)](mailto:jkomijani@gmail.com)**

# %% [markdown]
# # Introduction
#
# ## Diffusion process on Lie group
#
# Implements a diffusion process as described by the following stochastic
#     differential equation (SDE)
#
# $$
#     \frac{d U(t)}{dt} = e^{\gamma t}\sqrt{2\gamma}\,  \eta(t)\, U(t)
# $$
#
# where $\gamma > 0$ controls the rate of increament in the noise variance,
# $\sigma > 0$ controls the overal scale of the noise,
# $\eta(t)$ is standard white Gaussian noise in the algebra space.
# This diffusion process governs the evolution of a state on a Lie group,
# with the time-dependent, variance-expanding noise.
#
# The reverse process is defined by an SDE that uses a learned score function
# (the gradient of the log-probability density) to iteratively denoise the
# corrupted signal and recover clean samples.
# $$
#     \frac{d U(t)}{dt} = \left((- e^{2 \gamma t} \gamma + \tilde \sigma^2(t)) s_t(U_t) +  \sqrt{2} \tilde \sigma(t) \eta(t)\right) U_t
# $$
# Here $s_t$ is in Lie-algebra element. As two specail cases, we can set $\tilde \sigma(t)$ to zero or to $e^{\gamma t} \sqrt{\gamma}$.

# %%
import torch
import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["text.usetex"] = True

# %%
from lattice_ml.gauge_tools import WilsonGaugeAction
from lattice_ml.gauge_tools import GaugeLinkConv


from normflow.prior import SUnPrior

# %% [markdown]
# ### Designing score function
#
# The flow is defined as
# $$
#     \frac{d U(t)}{dt} = \left((- e^{2 \gamma t} \gamma + \tilde \sigma^2(t)) s_t(U_t) +  \sqrt{2} \tilde \sigma(t) \eta(t)\right) U_t
# $$
# Here $s_t$ is in Lie-algebra element. As two specail cases, we can set $\tilde \sigma(t)$ to zero or to $e^{\gamma t} \sqrt{\gamma}$.
#
#
# Below, we define a simple neural network for the score function.

# %%
action = WilsonGaugeAction(beta=4)


class GaugeSU3AlgScoreFunc(torch.nn.Module):
    """
    An algebra-element score function for SU(3) matrices.

    This model takes as input the time `t` and the initial state matrix `x` and
    predicts a flow while ensuring the output remains antihermitian and traceless.
    """

    def __init__(self):
        """Initializes the SU3DynamicsFunc neural network."""
        super().__init__()

        self.weight = torch.nn.Parameter(torch.tensor([1/32, 0, 0, 0, 0]))
        self.powers = torch.arange(5).reshape(1, -1)
        self.link_conv1 = GaugeLinkConv(None, None, spatial_ndim=2)
        self.link_conv2 = GaugeLinkConv(None, None, spatial_ndim=2)
        
    def forward(self, t: torch.Tensor, x: torch.Tensor) -> torch.Tensor:
        """
        Computes the algebra-element score function for SU(3) matrices.

        Given a time `t` and a matrix `x`, the function processes the input
        through the neural network and applies post-processing to ensure the
        output is antihermitian and traceless.

        Args:
            - t (torch.Tensor): A 0D or 1D tensor representing time.
              If 1D, it is of shape (batch_size,)
            - x (torch.Tensor): A complex-valued input tensor of shape
              (batch_size, 1, 3, 3).

        Returns:
            - torch.Tensor: A antihermitian, traceless tensor of shape
              (batch_size, 1, 3, 3).
        """
        # x = self.link_conv1(x)
        shape = (-1, *[1]*(x.ndim - 1))
        return action.algebra_force(x) * self.time_func(t).reshape(*shape)

    def time_func(self, t):
        """A polynomial function of time."""
        return torch.sum(self.weight * t.unsqueeze(-1) ** self.powers, dim=1)

# %%
training_samples = torch.load("/scratch/lturgut/cfgs1024_b4_2dim_200traj_15steps.pt", map_location="cuda:0")

from torch.utils.data import DataLoader, TensorDataset

batch_size = 1024 // 16

dataset = TensorDataset(training_samples)

data_loader = DataLoader(
    dataset,
    batch_size = batch_size,
    shuffle = False
)

# %%
from lattice_ml.diffusion.gauge import SUnDiffusionProcess

diffusion_process = SUnDiffusionProcess(GaugeSU3AlgScoreFunc())

# %%
from functools import partial

n_epochs = 0

train_kwargs = dict(
    n_epochs = n_epochs,
    hyperparam = dict(lr=0.003),
    checkpoint_dict = dict(print_every=50),
    scheduler = partial(
        torch.optim.lr_scheduler.CosineAnnealingLR,
        T_max = int(1.01 * n_epochs)              
    )
)

# %%
diffusion_process.train(data_loader, **train_kwargs)

# %%
fig, axs = plt.subplots(1, 1, figsize=(5, 3))

loss = diffusion_process.trainer.train_history['loss']
epochs = np.arange(1, len(loss) + 1)
plt.plot(epochs, loss, '.')


plt.grid()
plt.xlabel("Epoch")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
num_samples, *sample_shape, n_c, n_c = training_samples.shape

prior = SUnPrior(n_c, sample_shape)

x = prior.sample(16)

with torch.no_grad():
    y = diffusion_process.reverse(x, sigma_tilde=0, step_size=0.003)

# %%
from lattice_ml.gauge_tools import compute_mean_reduced_trace_wilson_mxn_loop

# %%
(compute_mean_reduced_trace_wilson_mxn_loop(training_samples, 1, 1).mean(),
 compute_mean_reduced_trace_wilson_mxn_loop(y, 1, 1).mean(),
 compute_mean_reduced_trace_wilson_mxn_loop(y, 1, 1).std()
)
# Out:
# (tensor(0.2798, device='cuda:0'),
#  tensor(0.7133, device='cuda:0'),
#  tensor(0.0093, device='cuda:0'))

# %%
from lattice_ml.gauge_tools import compute_wilson_1x1_loop


theta_x = torch.linalg.eig(compute_wilson_1x1_loop(x, 0, 1))[0].angle()
theta_y = torch.linalg.eig(compute_wilson_1x1_loop(y, 0, 1))[0].angle()

theta_test = torch.linalg.eig(compute_wilson_1x1_loop(training_samples, 0, 1))[0].angle()

# %%
grab = lambda x: x.detach().cpu().numpy()

theta_x = grab(theta_x)
theta_y = grab(theta_y)

theta_test = np.array([grab(q) for q in theta_test])

# %%
plt.hist(theta_x.ravel(), label = 'Prior', bins=100, density=True, alpha=0.5)
plt.hist(theta_y.ravel(), label = 'DM', bins=100, density=True, alpha=0.5)
plt.hist(theta_test.ravel(), label = 'True (HMC)', bins=100, density=True, alpha=0.5)

plt.legend();

# %%
diffusion_process.score_fn.weight * 16 / 3
# Out:
# tensor([0.5000, 0.0000, 0.0000, 0.0000, 0.0000], device='cuda:0',
#        grad_fn=<DivBackward0>)

# %%
t = torch.linspace(0, 1, 101)

with torch.no_grad():
    plt.plot(t, 16 / 3 * diffusion_process.score_fn.time_func(t) * torch.exp(1 * t))
    plt.plot(t, 16 / 3 * diffusion_process.score_fn.time_func(t))

plt.grid()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 4
#       1 t = torch.linspace(0, 1, 101)
#       3 with torch.no_grad():
# ----> 4     plt.plot(t, 16 / 3 * diffusion_process.score_fn.time_func(t) * torch.exp(1 * t))
#       5     plt.plot(t, 16 / 3 * diffusion_process.score_fn.time_func(t))
#       7 plt.grid()
#
# File /scratch/lturgut/.venv/lib/python3.13/site-packages/matplotlib/pyplot.py:3827, in plot(scalex, scaley, data, *args, **kwargs)
#    3819 @_copy_docstring_and_deprecators(Axes.plot)
#    3820 def plot(
#    3821     *args: float | ArrayLike | str,
#    (...)   3825     **kwargs,
#    3826 ) -> list[Line2D]:
# -> 3827     return gca().plot(
#    3828         *args,
#    3829         scalex=scalex,
#    3830         scaley=scaley,
#    3831         **({"data": data} if data is not None else {}),
#    3832         **kwargs,
#    3833     )
#
# File /scratch/lturgut/.venv/lib/python3.13/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)   1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File /scratch/lturgut/.venv/lib/python3.13/site-packages/matplotlib/axes/_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File /scratch/lturgut/.venv/lib/python3.13/site-packages/matplotlib/axes/_base.py:483, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     480         kw[prop_name] = val
#     482 if len(xy) == 2:
# --> 483     x = _check_1d(xy[0])
#     484     y = _check_1d(xy[1])
#     485 else:
#
# File /scratch/lturgut/.venv/lib/python3.13/site-packages/matplotlib/cbook.py:1361, in _check_1d(x)
#    1359 """Convert scalars to 1D arrays; pass-through arrays as is."""
#    1360 # Unpack in case of e.g. Pandas or xarray object
# -> 1361 x = _unpack_to_numpy(x)
#    1362 # plot requires `shape` and `ndim`.  If passed an
#    1363 # object that doesn't provide them, then force to numpy array.
#    1364 # Note this will strip unit information.
#    1365 if (not hasattr(x, 'shape') or
#    1366         not hasattr(x, 'ndim') or
#    1367         len(x.shape) < 1):
#
# File /scratch/lturgut/.venv/lib/python3.13/site-packages/matplotlib/cbook.py:2371, in _unpack_to_numpy(x)
#    2365         return xtmp
#    2366 if _is_torch_array(x) or _is_jax_array(x) or _is_tensorflow_array(x):
#    2367     # using np.asarray() instead of explicitly __array__(), as the latter is
#    2368     # only _one_ of many methods, and it's the last resort, see also
#    2369     # https://numpy.org/devdocs/user/basics.interoperability.html#using-arbitrary-objects-in-numpy
#    2370     # therefore, let arrays do better if they can
# -> 2371     xtmp = np.asarray(x)
#    2373     # In case np.asarray method does not return a numpy array in future
#    2374     if isinstance(xtmp, np.ndarray):
#
# File /scratch/lturgut/.venv/lib/python3.13/site-packages/torch/_tensor.py:1223, in Tensor.__array__(self, dtype)
#    1221 def __array__(self, dtype=None):
#    1222     if has_torch_function_unary(self):
# -> 1223         return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#    1224     if dtype is None:
#    1225         return self.numpy()
#
# File /scratch/lturgut/.venv/lib/python3.13/site-packages/torch/overrides.py:1721, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1717 if _is_torch_function_mode_enabled():
#    1718     # if we're here, the mode must be set to a TorchFunctionStackMode
#    1719     # this unsets it and calls directly into TorchFunctionStackMode's torch function
#    1720     with _pop_mode_temporarily() as mode:
# -> 1721         result = mode.__torch_function__(public_api, types, args, kwargs)
#    1722     if result is not NotImplemented:
#    1723         return result
#
# File /scratch/lturgut/.venv/lib/python3.13/site-packages/torch/utils/_device.py:104, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#     102 if func in _device_constructors() and kwargs.get('device') is None:
#     103     kwargs['device'] = self.device
# --> 104 return func(*args, **kwargs)
#
# File /scratch/lturgut/.venv/lib/python3.13/site-packages/torch/_tensor.py:1225, in Tensor.__array__(self, dtype)
#    1223     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#    1224 if dtype is None:
# -> 1225     return self.numpy()
#    1226 else:
#    1227     return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.
